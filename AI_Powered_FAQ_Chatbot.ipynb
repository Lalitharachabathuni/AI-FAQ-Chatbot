# %%
history = []

while True:
    q = input("You: ")

    history.append(q)
    history = history[-5:]

    if "admission" in q.lower():
        print("Bot: Admissions are open through the online portal.")
    elif "fees" in q.lower():
        print("Bot: Fees vary by course.")
    elif "placement" in q.lower():
        print("Bot: Placement assistance is available.")
    else:
        print("Bot: Sorry, this question is outside my knowledge domain.")
# Out:
# Bot: Admissions are open through the online portal.
# Bot: Placement assistance is available.
# Bot: Sorry, this question is outside my knowledge domain.
